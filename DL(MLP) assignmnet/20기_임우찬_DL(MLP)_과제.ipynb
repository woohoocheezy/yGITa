# %% [markdown]
# # 과제: MNIST 데이터를 나만의 NN model로 95 % 이상의 성능으로 training 시켜보자!
#
#
# ## Loading MNIST training data
#
# 출처: 18기 DS 김승하님

# %%
import tensorflow as tf
from tensorflow import keras

# import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline

# Loading the data
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.mnist.load_data()

# Scaling(image data는 min-max scaling 주로 사용)
x_train = x_train/255.0
x_test = x_test/255.0
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11493376/11490434 [==============================] - 0s 0us/step
# 11501568/11490434 [==============================] - 0s 0us/step

# %% [markdown]
# ## Training Data
# 28 * 28 pixel 값을 가진 총 60000개의 이미지 데이터

# %%
x_train.shape
# Out:
# (60000, 28, 28)

# %% [markdown]
# Neural network 모델에 맞게 이미지 데이터를 벡터 형태로 데이터를 reshape 합니다.
# (Model을 만들 때 *keras.layers.Flatten(input_shape=(28, 28)) 이용해도 됨)

# %%
x_train, x_test = x_train.reshape((-1, 28*28)), x_test.reshape((-1, 28*28))
x_train.shape, x_test.shape
# Out:
# ((60000, 784), (10000, 784))

# %%
# Hint: x_train[0].reshape()
plt.imshow(x_train[0].reshape(28,28)).set_cmap('Greys')

# %% [markdown]
# ## Training Labels
# 이미지 데이터가 나타내는 숫자값을 label로 가지고 있고, 0부터 9까지의 값을 나타냄
# 마찬가지로, 60000개의 label이 존재

# %%
y_train.shape
# Out:
# (60000,)

# %%
# show MNIST label for above data
y_train[0]
# Out:
# 5

# %% [markdown]
# ## 나만의 모델을 tensorflow keras API 를 이용해 만들어 봅시다~

# %% [markdown]
# * parameters for model

# %%
activation_list = ["sigmoid", "relu", "softmax", "tanh"]

loss_list = ["sparse_categorical_crossentropy",
             "categorical_crossentropy", 
             "binary_crossentropy"]

optimizer_list = ["sgd", "adam", "rmsprop", "adagrad"]

initializer_list = [tf.keras.initializers.RandomNormal(), 
                    tf.keras.initializers.RandomUniform(), 
                    tf.keras.initializers.he_normal(), 
                    tf.keras.initializers.he_uniform(), 
                    tf.keras.initializers.GlorotUniform(),
                    tf.keras.initializers.GlorotNormal()]

# dropout
dropout_rate = 0.3
model = tf.keras.Sequential([
    tf.keras.layers.Dense(256, input_dim=784, activation = "sigmoid"),
    tf.keras.layers.Dense(2, activation = "sigmoid"),
    tf.keras.layers.Dropout(dropout_rate)
])


# regularizer
regularizer = tf.keras.regularizers.l1(1e-3)
regularizer = tf.keras.regularizers.l2(1e-3)
model = tf.keras.Sequential([
    tf.keras.layers.Dense(256, input_dim=784, activation="sigmoid",
                          activity_regularizer=regularizer)
])

# weight initialization
model = tf.keras.Sequential([
    tf.keras.layers.Dense(256, input_dim=784, activation="sigmoid",
                          kernel_initializer=initializer_list[0])
])

# %% [markdown]
# #### My Own Model

# %%
#### 자유롭게 Model을 만들고 compile 해봅시다 ####
model = keras.models.Sequential()
model.add(keras.layers.Dense(128, input_dim=784, activation='relu'))
model.add(keras.layers.Dense(10, activation='softmax'))

model.compile(loss = "sparse_categorical_crossentropy", 
              optimizer = "sgd",
              metrics = ["accuracy"])

# %% [markdown]
# 내가 만든 모델을 확인해 봅시다.

# %%
model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_4 (Dense)             (None, 128)               100480
#
#  dense_5 (Dense)             (None, 10)                1290
#
# =================================================================
# Total params: 101,770
# Trainable params: 101,770
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# model을 자유롭게 train 해봅시다.

# %%
model.fit(x_train, y_train, epochs = 60, verbose=1, validation_split=0.2)
# Out:
# Epoch 1/60
# 1500/1500 [==============================] - 11s 5ms/step - loss: 0.7079 - accuracy: 0.8255 - val_loss: 0.3810 - val_accuracy: 0.8993
# Epoch 2/60
# 1500/1500 [==============================] - 5s 3ms/step - loss: 0.3675 - accuracy: 0.8989 - val_loss: 0.3132 - val_accuracy: 0.9119
# Epoch 3/60
# 1500/1500 [==============================] - 5s 3ms/step - loss: 0.3164 - accuracy: 0.9113 - val_loss: 0.2853 - val_accuracy: 0.9199
# Epoch 4/60
# 1500/1500 [==============================] - 5s 3ms/step - loss: 0.2865 - accuracy: 0.9199 - val_loss: 0.2626 - val_accuracy: 0.9275
# Epoch 5/60
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.2646 - accuracy: 0.9266 - val_loss: 0.2464 - val_accuracy: 0.9323
# Epoch 6/60
# 1500/1500 [==============================] - 5s 3ms/step - loss: 0.2462 - accuracy: 0.9317 - val_loss: 0.2306 - val_accuracy: 0.9363
# Epoch 7/60
# 1500/1500 [==============================] - 5s 3ms/step - loss: 0.2306 - accuracy: 0.9361 - val_loss: 0.2174 - val_accuracy: 0.9400
# Epoch 8/60
# 1500/1500 [==============================] - 5s 3ms/step - loss: 0.2170 - accuracy: 0.9397 - val_loss: 0.2072 - val_accuracy: 0.9440
# Epoch 9/60
# 1500/1500 [==============================] - 5s 3ms/step - loss: 0.2049 - accuracy: 0.9433 - val_loss: 0.1992 - val_accuracy: 0.9455
# Epoch 10/60
# 1500/1500 [==============================] - 5s 3ms/step - loss: 0.1943 - accuracy: 0.9459 - val_loss: 0.1888 - val_accuracy: 0.9498
# Epoch 11/60
# 1500/1500 [==============================] - 4s 3ms/step - loss: 0.1849 - accuracy: 0.9480 - val_loss: 0.1823 - val_accuracy: 0.9506
# Epoch 12/60
# 1500/1500 [==============================] - 5s 3ms/step - loss: 0.1762 - accuracy: 0.9507 - val_loss: 0.1751 - val_accuracy: 0.9529
# Epoch 13/60
# 1500/1500 [==============================] - 4s 3ms/step - loss: 0.1683 - accuracy: 0.9529 - val_loss: 0.1698 - val_accuracy: 0.9533
# Epoch 14/60
# 1500/1500 [==============================] - 5s 3ms/step - loss: 0.1607 - accuracy: 0.9548 - val_loss: 0.1641 - val_accuracy: 0.9558
# Epoch 15/60
# 1500/1500 [==============================] - 5s 3ms/step - loss: 0.1541 - accuracy: 0.9565 - val_loss: 0.1590 - val_accuracy: 0.9569
# Epoch 16/60
# 1500/1500 [==============================] - 5s 3ms/step - loss: 0.1480 - accuracy: 0.9583 - val_loss: 0.1543 - val_accuracy: 0.9575
# Epoch 17/60
# 1500/1500 [==============================] - 5s 3ms/step - loss: 0.1420 - accuracy: 0.9605 - val_loss: 0.1490 - val_accuracy: 0.9589
# Epoch 18/60
# 1500/1500 [==============================] - 5s 3ms/step - loss: 0.1367 - accuracy: 0.9621 - val_loss: 0.1465 - val_accuracy: 0.9600
# Epoch 19/60
# 1500/1500 [==============================] - 5s 3ms/step - loss: 0.1319 - accuracy: 0.9638 - val_loss: 0.1427 - val_accuracy: 0.9612
# Epoch 20/60
# 1500/1500 [==============================] - 5s 3ms/step - loss: 0.1271 - accuracy: 0.9644 - val_loss: 0.1390 - val_accuracy: 0.9618
# Epoch 21/60
# 1500/1500 [==============================] - 5s 3ms/step - loss: 0.1228 - accuracy: 0.9660 - val_loss: 0.1366 - val_accuracy: 0.9622
# Epoch 22/60
# 1500/1500 [==============================] - 5s 3ms/step - loss: 0.1186 - accuracy: 0.9675 - val_loss: 0.1328 - val_accuracy: 0.9632
# Epoch 23/60
# 1500/1500 [==============================] - 5s 3ms/step - loss: 0.1146 - accuracy: 0.9688 - val_loss: 0.1301 - val_accuracy: 0.9631
# Epoch 24/60
# 1500/1500 [==============================] - 5s 3ms/step - loss: 0.1110 - accuracy: 0.9694 - val_loss: 0.1270 - val_accuracy: 0.9638
# Epoch 25/60
# 1500/1500 [==============================] - 4s 3ms/step - loss: 0.1076 - accuracy: 0.9707 - val_loss: 0.1250 - val_accuracy: 0.9650
# Epoch 26/60
# 1500/1500 [==============================] - 5s 3ms/step - loss: 0.1042 - accuracy: 0.9716 - val_loss: 0.1239 - val_accuracy: 0.9657
# Epoch 27/60
# 1500/1500 [==============================] - 5s 3ms/step - loss: 0.1009 - accuracy: 0.9729 - val_loss: 0.1202 - val_accuracy: 0.9656
# Epoch 28/60
# 1500/1500 [==============================] - 5s 3ms/step - loss: 0.0982 - accuracy: 0.9738 - val_loss: 0.1183 - val_accuracy: 0.9656
# Epoch 29/60
# 1500/1500 [==============================] - 5s 3ms/step - loss: 0.0952 - accuracy: 0.9744 - val_loss: 0.1173 - val_accuracy: 0.9664
# Epoch 30/60
# 1500/1500 [==============================] - 5s 3ms/step - loss: 0.0926 - accuracy: 0.9750 - val_loss: 0.1154 - val_accuracy: 0.9674
# Epoch 31/60
# 1500/1500 [==============================] - 5s 3ms/step - loss: 0.0902 - accuracy: 0.9760 - val_loss: 0.1136 - val_accuracy: 0.9677
# Epoch 32/60
# 1500/1500 [==============================] - 5s 3ms/step - loss: 0.0877 - accuracy: 0.9765 - val_loss: 0.1123 - val_accuracy: 0.9684
# Epoch 33/60
# 1500/1500 [==============================] - 5s 3ms/step - loss: 0.0853 - accuracy: 0.9771 - val_loss: 0.1102 - val_accuracy: 0.9682
# Epoch 34/60
# 1500/1500 [==============================] - 5s 3ms/step - loss: 0.0832 - accuracy: 0.9775 - val_loss: 0.1093 - val_accuracy: 0.9684
# Epoch 35/60
# 1500/1500 [==============================] - 5s 3ms/step - loss: 0.0809 - accuracy: 0.9781 - val_loss: 0.1095 - val_accuracy: 0.9683
# Epoch 36/60
# 1500/1500 [==============================] - 5s 3ms/step - loss: 0.0791 - accuracy: 0.9787 - val_loss: 0.1071 - val_accuracy: 0.9703
# Epoch 37/60
# 1500/1500 [==============================] - 5s 3ms/step - loss: 0.0770 - accuracy: 0.9790 - val_loss: 0.1048 - val_accuracy: 0.9703
# Epoch 38/60
# 1500/1500 [==============================] - 5s 3ms/step - loss: 0.0751 - accuracy: 0.9799 - val_loss: 0.1054 - val_accuracy: 0.9701
# Epoch 39/60
# 1500/1500 [==============================] - 5s 3ms/step - loss: 0.0734 - accuracy: 0.9798 - val_loss: 0.1046 - val_accuracy: 0.9700
# Epoch 40/60
# 1500/1500 [==============================] - 5s 3ms/step - loss: 0.0716 - accuracy: 0.9806 - val_loss: 0.1026 - val_accuracy: 0.9708
# Epoch 41/60
# 1500/1500 [==============================] - 5s 3ms/step - loss: 0.0700 - accuracy: 0.9813 - val_loss: 0.1024 - val_accuracy: 0.9715
# Epoch 42/60
# 1500/1500 [==============================] - 5s 3ms/step - loss: 0.0683 - accuracy: 0.9819 - val_loss: 0.1006 - val_accuracy: 0.9721
# Epoch 43/60
# 1500/1500 [==============================] - 5s 3ms/step - loss: 0.0667 - accuracy: 0.9822 - val_loss: 0.0992 - val_accuracy: 0.9724
# Epoch 44/60
# 1500/1500 [==============================] - 5s 3ms/step - loss: 0.0652 - accuracy: 0.9827 - val_loss: 0.0994 - val_accuracy: 0.9718
# Epoch 45/60
# 1500/1500 [==============================] - 5s 3ms/step - loss: 0.0638 - accuracy: 0.9835 - val_loss: 0.0982 - val_accuracy: 0.9716
# Epoch 46/60
# 1500/1500 [==============================] - 4s 3ms/step - loss: 0.0623 - accuracy: 0.9835 - val_loss: 0.0983 - val_accuracy: 0.9732
# Epoch 47/60
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.0610 - accuracy: 0.9841 - val_loss: 0.0968 - val_accuracy: 0.9723
# Epoch 48/60
# 1500/1500 [==============================] - 5s 3ms/step - loss: 0.0597 - accuracy: 0.9844 - val_loss: 0.0959 - val_accuracy: 0.9729
# Epoch 49/60
# 1500/1500 [==============================] - 4s 3ms/step - loss: 0.0584 - accuracy: 0.9850 - val_loss: 0.0961 - val_accuracy: 0.9722
# Epoch 50/60
# 1500/1500 [==============================] - 5s 3ms/step - loss: 0.0572 - accuracy: 0.9854 - val_loss: 0.0947 - val_accuracy: 0.9729
# Epoch 51/60
# 1500/1500 [==============================] - 5s 3ms/step - loss: 0.0559 - accuracy: 0.9858 - val_loss: 0.0947 - val_accuracy: 0.9733
# Epoch 52/60
# 1500/1500 [==============================] - 5s 3ms/step - loss: 0.0549 - accuracy: 0.9861 - val_loss: 0.0936 - val_accuracy: 0.9728
# Epoch 53/60
# 1500/1500 [==============================] - 5s 3ms/step - loss: 0.0537 - accuracy: 0.9863 - val_loss: 0.0942 - val_accuracy: 0.9722
# Epoch 54/60
# 1500/1500 [==============================] - 5s 3ms/step - loss: 0.0527 - accuracy: 0.9866 - val_loss: 0.0931 - val_accuracy: 0.9735
# Epoch 55/60
# 1500/1500 [==============================] - 5s 3ms/step - loss: 0.0517 - accuracy: 0.9866 - val_loss: 0.0924 - val_accuracy: 0.9734
# Epoch 56/60
# 1500/1500 [==============================] - 5s 3ms/step - loss: 0.0505 - accuracy: 0.9874 - val_loss: 0.0930 - val_accuracy: 0.9732
# Epoch 57/60
# 1500/1500 [==============================] - 5s 3ms/step - loss: 0.0496 - accuracy: 0.9874 - val_loss: 0.0915 - val_accuracy: 0.9744
# Epoch 58/60
# 1500/1500 [==============================] - 5s 4ms/step - loss: 0.0485 - accuracy: 0.9876 - val_loss: 0.0918 - val_accuracy: 0.9737
# Epoch 59/60
# 1500/1500 [==============================] - 5s 3ms/step - loss: 0.0477 - accuracy: 0.9881 - val_loss: 0.0908 - val_accuracy: 0.9735
# Epoch 60/60
# 1500/1500 [==============================] - 5s 3ms/step - loss: 0.0468 - accuracy: 0.9883 - val_loss: 0.0898 - val_accuracy: 0.9748

# %% [markdown]
# 95%이상의 성능을 가진 모델을 만들면 완성!

# %%
test_loss, test_acc = model.evaluate(x_test,y_test, verbose=2)

print('\nAccuracy:', test_acc)
# Out:
# 313/313 - 1s - loss: 0.0834 - accuracy: 0.9752 - 930ms/epoch - 3ms/step
#
# Accuracy: 0.9751999974250793

# %% [markdown]
# ![](https://www.tensorflow.org/versions/master/images/mnist_tensorboard.png)
